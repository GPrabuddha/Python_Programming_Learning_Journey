# %% [markdown]
# # 1. Programming as a way of Thinking

# %% [markdown]
# ## 1.1 Arithmetic Operators

# %%
integer_1, integer_2 = 5, 10
float_1, float_2 = 7.0, 3.0

add = integer_1 + integer_2
subtract = integer_2 - integer_1
multiply = integer_1 * integer_2
division = integer_2 / integer_1

print("Addition result & type: ", add, type(add),"\n", 
    "Subtraction result & type: ",subtract, type(subtract), "\n",
    "Multiplication result & type: ", multiply, type(multiply), "\n",
    "Division result & type: ", division, type(division), "\n")  # division of two integers can be float so it is set to float automatically

integer_division_or_floor_division = integer_1 // integer_2  # we get floor value so called floor division

print("Integer division or Floor division result & type: ",integer_division_or_floor_division, type(integer_division_or_floor_division))

exponentiation_int = integer_1 ** integer_2
exponentiation_float = float_1 ** float_2
exponentiation = integer_1 ** float_1


print("Exponentiation result and type: ", exponentiation_int, type(exponentiation_int))
print("Exponentiation result and type: ", exponentiation_float, type(exponentiation_float))
print("exponentiation result and type: ", exponentiation, type(exponentiation))

# %% [markdown]
# ## 1.2 Expressions
#
# A collection of variables, operators and values is called an expression.
#
# value: An integer, floating-point number, or string – or one of other kinds of values we will see later.

# %%
12 + 5 * 6

# %% [markdown]
# ## 1.3 Arithmetic Functions

# %%
# round -> rounds to nearest integer
print("Round function output:", round(42.3), round(42.5), round(42.6))

# abs -> computes absolute value of a number
print("Absolute function output: ", abs(42), abs(-42))

abs # a function name by itself if a legal expression

# %% [markdown]
# ## 1.4 Strings

# %%
"spam " * 4 # * makes multiple copies of a string and concatenates them

# %%
help(len)

# %% [markdown]
# ## 1.5 Values and Types

# %%
print(int(42.5), float(63), int("452"), float("129"))
1_000_000 # use underscores to make large numbers easier to read, comma doesn't work

# %% [markdown]
# ## 1.6 Formal and Natural Languages
# Natural language: Languages that we speak
#
# Formal language: Languages that are designed by people for specific applications
#     Ex. Programming languages are formal languages
# Although formal and natural languages have some features in common there are important differences:
#
#     1. Ambiguity: Natural languages are full of ambiguity, which people deal with by using contextual clues and other information. Formal languages are designed to be nearly or completely unambiguous, which means that any program has exactly one meaning, regardless of context.
#
#     2. Redundancy: In order to make up for ambiguity and reduce misunderstandings, natural languages use redundancy. As a result, they are often verbose. Formal languages are less redundant and more concise.
#
#     3. Literalness: Natural languages are full of idiom and metaphor. Formal languages mean exactly what they say.

# %% [markdown]
# ## 1.7 Debugging
# syntax error: An error in a program that makes it impossible to parse – and therefore impossible to run.

# %% [markdown]
# ## 1.8 Exercises

# %% [markdown]
# ### 1.8.1 Bitwise Operators

# %%
x = 12 # 1100
y = 10 # 1010

print("bitwise and: ", x&y)
print("bitwise or: ", x|y)
print("bitwise xor: ", x^y)

n = 2
# Python shift is arithmetic shift (filled with 1 i.e. sign bit preserved) not logical shift (filled with 0)
# logical shift might be useful when dealing with unsigned integers
print("bitwise left shift (multiply by 2^n): ", x<<n) # multiply by 2^n
print("bitwise right shift (divide by 2^n): ", x>>n) # divide by 2^n
print("bitwise shift on negative numbers (preserves sign as it is arithmetic shift): ", -8 >> -4)

print("negation:", ~y)
# why -11? -> python uses 2's complement therefore ~ x = -(x + 1)

# %%
# PYTHON OPERATOR PRECEDENCE

print("1️⃣ Parentheses ()  → Grouping")
print("(2 + 3) * 4 =", (2 + 3) * 4)
print()

print("2️⃣ Exponentiation **  → Power (Right-Associative)")
print("2 ** 3 ** 2 =", 2 ** 3 ** 2)
print()

print("3️⃣ Unary Operators (+x, -x, ~x)")
print("+5 =", +5)                  # Unary Plus
print("-5 =", -5)                  # Unary Minus
print("~5 =", ~5)                  # Bitwise NOT
print()

print("4️⃣ Multiplicative (*, /, //, %)")
print("6 * 3 =", 6 * 3)            # Multiplication
print("7 / 2 =", 7 / 2)            # Division
print("7 // 2 =", 7 // 2)          # Floor Division
print("7 % 2 =", 7 % 2)            # Modulus
print()

print("5️⃣ Additive (+, -)")
print("5 + 2 =", 5 + 2)            # Addition
print("5 - 2 =", 5 - 2)            # Subtraction
print()

print("6️⃣ Bitwise Shift (<<, >>)")
print("5 << 1 =", 5 << 1)          # Left Shift
print("8 >> 2 =", 8 >> 2)          # Right Shift
print()

print("7️⃣ Bitwise AND (&)")
print("5 & 3 =", 5 & 3)
print()

print("8️⃣ Bitwise XOR (^)")
print("5 ^ 3 =", 5 ^ 3)
print()

print("9️⃣ Bitwise OR (|)")
print("5 | 3 =", 5 | 3)
print()

print("🔟 Comparisons (==, !=, >, <, >=, <=, in, is)")
print("5 > 3 =", 5 > 3)
print("5 == 3 =", 5 == 3)
print("3 in [1,2,3] =", 3 in [1,2,3])
print()

print("1️⃣1️⃣ Logical NOT (not)")
print("not True =", not True)
print()

print("1️⃣2️⃣ Logical AND (and)")
print("True and False =", True and False)
print()

print("1️⃣3️⃣ Logical OR (or)")
print("True or False =", True or False)
print()

print("1️⃣4️⃣ Assignment (=, +=, etc.)")
x = 5
x += 3
print("x after x += 3:", x)
print()

print("1️⃣5️⃣ Lambda (Anonymous Function)")
square = lambda n: n * n
print("square(4) =", square(4))

# %%
# =========================================
# MIXED OPERATOR PRECEDENCE — SINGLE BLOCK
# =========================================

print("Example 1:")
expr1 = -3 + 2 ** 3 * 4 >> 1
print("Expression: -3 + 2 ** 3 * 4 >> 1")
print("Result:", expr1)
print()

print("Example 2:")
expr2 = 5 + 2 & 3 == 1 or False
print("Expression: 5 + 2 & 3 == 1 or False")
print("Result:", expr2)
print()

print("Example 3:")
expr3 = not 8 >> 2 == 2 and 3 | 1 ^ 1
print("Expression: not 8 >> 2 == 2 and 3 | 1 ^ 1")
print("Result:", expr3)
print()

print("Example 4:")
square = lambda x: x * x
x = 3
expr4 = square(x) + 4 * 2 > 15 and True
print("Expression: square(x) + 4 * 2 > 15 and True")
print("Result:", expr4)
print()

# %%
help(round)

# %% [markdown]
# ### 1.8.2

# %%
print(round(42.5), round(43.5), round(44.5), round(45.5))
# Q. If a number ends in 0.5, does Python round up or down?
    # A. Python uses “round half to even” (also called Banker’s Rounding).
    #    So if a number ends in .5, Python rounds to the nearest even number, not always up.
        # If the nearest integer is even → round to that
        # If the nearest integer is odd → round to the other (even) one

# Q. Why python does this
    # A. Because this reduces statistical bias in large datasets.
    # If we always rounded .5 upward, Over many calculations, The results would drift upward,“Round half to even” balances rounding errors.

# %% [markdown]
# ### 1.8.3

# %%
# first one is treated as binary operator and 2nd is unary
print(2--2)   # 2 - (-2) = 4
print(2+-2)   # 2 + (-2) = 0
print(2-+2)   # 2 - (+2) = 0

# %%
round(42.5

# %%
round42.5)

# %%
round42.5

# %%
type(abs)

# %% [markdown]
# # 2. Variables and Statements
# Variable: A variable is a name that referes to a value.
#
#     - after creating a variable you can use it as an expression
#     - When you call a function, the expression in parenthesis is called an argument.
#     - Comments are most useful when they document non-obvious features of the code. It is reasonable to assume that the reader can figure out what the code does; it is more useful to explain why.

# %% [markdown]
# ## Debugging
#     Three kinds of errors can occur in a program: syntax errors, runtime errors, and semantic errors. It is useful to distinguish between them in order to track them down more quickly.
#
# Syntax error: “Syntax” refers to the structure of a program and the rules about that structure. If there is a syntax error anywhere in your program, Python does not run the program. It displays an error message immediately.
#
# Runtime error: If there are no syntax errors in your program, it can start running. But if something goes wrong, Python displays an error message and stops. This type of error is called a runtime error. It is also called an exception because it indicates that something exceptional has happened.
#
# Semantic error: The third type of error is “semantic”, which means related to meaning. If there is a semantic error in your program, it runs without generating error messages, but it does not do what you intended. Identifying semantic errors can be tricky because it requires you to work backward by looking at the output of the program and trying to figure out what it is doing.

# %% [markdown]
# ## Exercises

# %%
17 = n

# %%
x = y = z = 5

# %%
print(x, y, z)

# %%
n =7; a=6 # semi-colon is a statement separator in Python

# %%
print(n, a)

# %%
import maath

# %%
x =7.
l = 5 + n.

# %%
print(x)
print(l)

# %%
import math
radius = 5
volume = 4 * math.pi * (radius**2) # radius is in cm and volume is in cubic centimeter
print(volume)

# %%
angle=42.0
print(pow(math.sin(angle), 2) + pow(math.cos(angle), 2))

# %%
print(math.e ** 2)
print(pow(math.e, 2))
print(math.exp(2))

# %% [markdown]
# # 3. Functions
# The first line of the function definition is called the header – the rest is called the body.

# %% [markdown]
# # 4. Functions & Interfaces
#
# Interface Design: It is a way of designing functions that work together.

# %%
# import jupyturtle
from jupyturtle import make_turtle
from jupyturtle import forward
from jupyturtle import left
from jupyturtle import right

# %%
# Iteration 1
# jupyturtle.make_turtle()
# jupyturtle.forward(100)

# Iteration 2
# make_turtle()
# forward(50)
# left(90)
# forward(50)
# left(90)
# forward(50)
# left(90)
# forward(50)

# Iteration 3
make_turtle()
for i in range(4):
    forward(50)
    left(90)

# %% [markdown]
# ## 4.1 Encapsulation and Generalization
#
# Encapsulation: Wrapping a piece of code in a function is called "Encapsulation".
#
# Generalization: Adding a parameter to a function is called "Generalization". (because it makes function more general)

# %%
# Wrapping a piece of code in a function is called "Encapsulation".
# Iteration 1
# def square():
#     for i in range(4):
#         forward(50)
#         left(90)

# make_turtle()
# square()

# Iteration 2 
def square(length):
    for i in range(4):
        forward(length)
        left(90)
make_turtle()
square(10)
square(40)
square(70)

# %%
# Generalization
def polygon(n, length):
    angle = 360/n
    for i in range(n):
        forward(length)
        left(angle)
make_turtle()
polygon(9, 30)
polygon(7, 10)
polygon(n=14, length=20)

# %%
import math
def circle(radius):
    circumference = 2 * math.pi * radius
    n = 30
    length = circumference/n
    polygon(n,length)

make_turtle(delay=0.02)
circle(25)

# %% [markdown]
# ## 4.2 Refactoring
# Changes which improve the code without changing its behavior, are called refactoring.

# %%
def polyline(n, length, angle):
    for i in range(n):
        forward(length)
        left(angle)

def polygon(n, length):
    angle = 360.0 / n
    polyline(n, length, angle)

def arc(radius, angle):
    arc_length = 2 * math.pi * radius * angle / 360
    n = 30
    length = arc_length / n
    step_angle = angle / n
    polyline(n, length, step_angle)

def circle(radius):
    arc(radius, 360) # this is a general version of a circle

make_turtle(delay=0)
polygon(n=20, length=9)
arc(radius=20, angle=270)
circle(radius=10)

# %% [markdown]
# ## 4.3 A development plan
# 1. Start by writing a small program with no functional definitions
# 2. Identify a coherent piece and encapsulate in a function
# 3. Generalize the function by adding approximate parameters
# 4. Repeat step 1 to 3 until you have a set of working functions.
# 5. Look for opportunites to improve program by refactoring.
# ex. if there is similar code in several places, we can consider factoring it into an appropriately general function.

# %% [markdown]
# The design of a function has two parts:
#
# The **Interface** is how the function is used, including its name, the parameters it takes and what the function is supposed to do.
#
# The **Implementation** is how the function does what it's supposed to do.
#
# Above two functions of circle have the same interface - they take the same parameters and do the same thing - but they have different implementations.

# %% [markdown]
# ## 4.4 Docstrings
#
# A docstring is a string at the beginning of a function that explains the interface ("doc" is short for documentation).
#
# A docstring should:
# 1. Explain concisely what the function does, without getting into the details of how it workd
# 2. Explain what effect each parameter has on the behavior of the function
# 3. Indicate what type each parameter should be, if it is not obvious.

# %%
def polyline(n, length, angle):
    """Draws line segments with the given length and angle between them.
    n: integer number of line segments
    length: length of the line segments
    angle: angle between segments (in degrees)
    """
    for i in range(n):
        forward(length)
        left(angle)

# %% [markdown]
# ## 4.5 Exercises

# %%
# function to draw a rectangle
from jupyturtle import forward, left, right, make_turtle

# %%
def rectangle(length, width):
    forward(length)
    left(90)
    forward(width)
    left(90)
    forward(length)
    left(90)
    forward(width)
make_turtle()
rectangle(80, 40)

# %%
def rhombus(length, angle):
    forward(length)
    left(180-angle)
    forward(length)
    left(angle)
    forward(length)
    left(180-angle)
    forward(length)
make_turtle()
rhombus(50, 60)

# %%
# Generalization
def parallelogram(length, width, angle):
    forward(length)
    left(180-angle)
    forward(width)
    left(angle)
    forward(length)
    left(180-angle)
    forward(width)

# Refactoring
def rectangle(length, width):
    parallelogram(length, width, 90)
def rhombus(length, angle):
    parallelogram(length, length, angle)

make_turtle()
rectangle(80, 40)
make_turtle()
rhombus(50, 60)

# %%
# Exercise 4
def triangle(side_length):
    forward(side_length)
    left(120)
    forward(side_length)
    left(120)
    forward(side_length)

# make_turtle()
# triangle(50)

# from this i figures out that with increase in number of sides angle in triangle changes so in next draw pie i accomodate it
# also that my prev triangle is just equilateral triangle and in given exercise we need isosceles triangle
# def draw_pie(length, num_sides):
#     for i in range(num_sides):
#         triangle(length)
#         left(60)

import math
# as knowing side-angle-side can uniquely determine a triangle, (angle is betn given sides)
def isosceles_triangle(side_length, angle):
    angle_2 = (180 - angle) / 2 # degrees
    # third_side = math.sqrt(2 * pow(side_length, 2) * (1 - math.cos(angle))) # issue with this was that math.cos expects angle in radians
    third_side = math.sqrt(2 * side_length**2 * (1-math.cos(math.radians(angle))))
    # third_side = side_length
    # print(third_side)
    forward(side_length)
    left(180-angle_2)
    forward(third_side)
    left(180-angle_2)
    forward(side_length)

# make_turtle()
# isosceles_triangle(50, 90)


# after finishing isosceles triangle now we can write draw pie
def draw_pie(length, num_sides):
    if num_sides <= 2:
        raise ValueError("Number of sides must be greater than 2")
    angle = 360/num_sides
    for i in range(num_sides):
        isosceles_triangle(length, angle)
        # left(120-angle) # this was the error caused by not understanding geometry properly 
        # as isosceles triangle will have slanted edge we need to use 180 - 2x to find the angle to move with
        left(180 - 2 * angle)


# I used below code to understand 180 -2 * theta is needed
# make_turtle()
# isosceles_triangle(50, 70)
# left(120-80)
# isosceles_triangle(50,70)
# left(120-80)
# isosceles_triangle(50,70)
# left(120-80)
# isosceles_triangle(50,70)
# left(120-80)
# isosceles_triangle(50,70)

# draw_pie(50, 4)


make_turtle()
draw_pie(50, 9)
# draw_pie(70, 7)

# %% [markdown]
# # 5 Conditionals and Recursion

# %% [markdown]
# ## 5.1 Integer division and Modulus
#
# The integer division operator, //, divides two numbers and rounds down to an integer.
#
# The modulus operator, %, which divides two numbers and returns the remainder.
#
# Uses of Modulus operator:
# 1. it can check whether one number is divisible by another – if x % y is zero, then x is divisible by y.
# 2. it can extract the right-most digit or digits from a number. For example, x % 10 yields the right-most digit of x (in base 10). Similarly, x % 100 yields the last two digits.
# 3. the modulus operator can do “clock arithmetic”. For example, if an event starts at 11 AM and lasts three hours, we can use the modulus operator to figure out what time it ends.

# %%
start = 11
duration = 3
end = (start + duration) % 12
print(end)
# Out:
# 2

# %% [markdown]
# ## 5.2 Recursion
#
# A function that calls itself is called recursive function.

# %%
def countdown(n):
    if n <= 0:
        print("Blastoff")
    else:
        print(n)
        countdown(n-1)
countdown(3)
# Out:
# 3
# 2
# 1
# Blastoff

# %% [markdown]
# ## 5.3 Keyboard Input
# Python provides a built-in function called input that stops the program and waits for the user to type something. When the user presses Return or Enter, the program resumes and input returns what the user typed as a string.

# %%
name = input("what is your name?")
name
# Out:
# 'Prabuddha'

# %% [markdown]
# ## 5.4 Debugging
#
# When a syntax or runtime error occurs, the error message contains a lot of information, but it can be overwhelming. The most useful parts are usually:
#
# 1) What kind of error it was, and
# 2) Where it occurred.

# %%
x = 5
 y = 6

# In this example, the problem is that the second line is indented by one space. But the error message points to y, 
# which is misleading. Error messages indicate where the problem was discovered, but the actual error might be earlier in the code.
# Out:
#   Cell In[4], line 2
#     y = 6
#     ^
# IndentationError: unexpected indent

# %%
import math
numerator = 9
denominator = 10
ratio = numerator // denominator
decibels = 10 * math.log10(ratio)

# the same is true for runtime error
# The error message indicates line 5, but there is nothing wrong with that line. The problem is in line 4, which uses 
# integer division instead of floating-point division – as a result, the value of ratio is 0. When we call math.log10, 
# we get a ValueError with the message math domain error, because 0 is not in the “domain” of valid arguments for math.log10,
#  because the logarithm of 0 is undefined.
# In general, you should take the time to read error messages carefully, but don’t assume that everything they say is correct.
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 5
#       3 denominator = 10
#       4 ratio = numerator // denominator
# ----> 5 decibels = 10 * math.log10(ratio)
#       7 # the same is true for runtime error
#       8 # The error message indicates line 5, but there is nothing wrong with that line. The problem is in line 4, which uses
#       9 # integer division instead of floating-point division – as a result, the value of ratio is 0. When we call math.log10,
#      10 # we get a ValueError with the message math domain error, because 0 is not in the “domain” of valid arguments for math.log10,
#      11 #  because the logarithm of 0 is undefined.
#      12 # In general, you should take the time to read error messages carefully, but don’t assume that everything they say is correct.
#
# ValueError: math domain error

# %% [markdown]
# ## 5.5 Exercises

# %% [markdown]
# ### Exercise 2

# %%
from time import time
now = time()
now
# Out:
# 1772871050.5543962

# %%
# each day have 24 hours
seconds_per_day = 24 * 60 * 60
no_of_days = now // seconds_per_day
print(no_of_days)
seconds_in_current_day = now % seconds_per_day
print(seconds_in_current_day)
seconds_per_hour = 60 * 60
hours_in_current_day = seconds_in_current_day // seconds_per_hour
print(hours_in_current_day)
# Out:
# 20519.0
# 29450.554396152496
# 8.0

# %% [markdown]
# ### Exercise 3

# %%
def is_triangle(a, b, c):
    """If any of the three lengths is greater than the sum of the other two, then you cannot form a triangle."""
    if (a > b + c) or (b > a + c) or (c > a + b):
        print('NO')
    else:
        print("YES")

is_triangle(3, 4, 5)
# Out:
# YES

# %% [markdown]
# ### Exercise 5

# %%
from jupyturtle import forward, left, right, back, make_turtle

def draw(length):
    angle = 50
    factor = 0.6
    
    if length > 5:
        forward(length)
        left(angle)
        draw(factor * length)
        right(2 * angle)
        draw(factor * length)
        left(angle)
        back(length)
make_turtle()
draw(40)
# Out:
# <svg width="300" height="150" style="fill:none; stroke-linecap:round;">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
#
# <path stroke="#663399" stroke-width="2" d="M 150,75 190,75 205.4,56.6 202.9,42.4 195.4,38.1 190.6,39.9 195.4,38.1 194.5,33 195.4,38.1 202.9,42.4 208.5,35.8 207.6,30.7 208.5,35.8 213.7,35.8 208.5,35.8 202.9,42.4 205.4,56.6 219.8,56.6 225.4,50 224.5,44.9 225.4,50 230.6,50 225.4,50 219.8,56.6 225.4,63.2 230.6,63.2 225.4,63.2 224.5,68.3 225.4,63.2 219.8,56.6 205.4,56.6 190,75 205.4,93.4 219.8,93.4 225.4,86.8 224.5,81.7 225.4,86.8 230.6,86.8 225.4,86.8 219.8,93.4 225.4,100 230.6,100 225.4,100 224.5,105.1 225.4,100 219.8,93.4 205.4,93.4 202.9,107.6 208.5,114.2 213.7,114.2 208.5,114.2 207.6,119.3 208.5,114.2 202.9,107.6 195.4,111.9 194.5,117 195.4,111.9 190.6,110.1 195.4,111.9 202.9,107.6 205.4,93.4 190,75 150,75" />'
#
# <g transform="rotate(-90.0,150.0,75.0) translate(150.0, 75.0)">
# ...
